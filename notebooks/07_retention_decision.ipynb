# %% [markdown]
# Clean data
# ↓
# Load data
# ↓
# Define target and features
# ↓
# Stratified split → 70% train / 15% validation / 15% test
# ↓
# Build preprocessing + model pipelines
# (StandardScaler for numeric, OneHotEncoder for categorical)
# ↓
# Baseline training on TRAIN set
# ↓
# Hyperparameter tuning using Stratified CV on TRAIN set
# (scoring = PR-AUC)
# ↓
# Select best models based on CV PR-AUC
# ↓
# Probability calibration on VALIDATION set
# Brier Score
# Calibration Curve (Reliability Curve)
# ↓
# Threshold optimization on VALIDATION set
# (catch churners efficiently, Recall subject to precision ≥ X)
# ↓
# Lock model + threshold
# ↓
# Final evaluation on TEST set
# (report PR-AUC, ROC-AUC, Recall, Precision, F1)
# Recall & Precision vs Threshold
# X-axis: Threshold (0 → 1)
# Y-axis: Metric value (0 → 1)
#
# Confusion Matrix (at chosen threshold)

# %% [markdown]
# retenten logic
# retention strategy

# %%
action_list = {
    "Apply 10% Monthly Discount (6 Months)",
    "Offer 12-Month Contract With Discount",
    "Activate Free Streaming Bundle (3 Months)",
    "Activate Free TechSupport + OnlineSecurity (60 Days)",
    "Downgrade to Cheaper Plan",
    "Device / Router Upgrade Offer",
    "Proactive Retention Call",
    "Apply One-Time Bill Credit",
    "Early Tenure Welcome Bonus",
    "Upgrade Network (DSL → Fiber)",
    "Loyalty Reward (Points / Cashback)",
    "Migrate Electronic Check → Auto-Payment",
    "No Action / Upsell Only"
}

# %% [markdown]
# Review this Jupyter notebook (cell by cell) for cleanliness, organization, and Python best practices. Do NOT change logic or behavior. Suggest only surgical fixes for readability and maintainability, avoid excessive comments, and add comments only when necessary. If any reorganization is absolutely required, explicitly explain why. Clearly specify every change with exact cell and line numbers.
